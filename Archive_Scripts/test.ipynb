# %%
import torch
if torch.cuda.is_available():
    print("GPU is ON!")
else:
    print("Running on CPU")
# Out:
# GPU is ON!

# %%
# %pip install roboflow
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    - -------------------------------------- 1.8/38.8 MB 9.1 MB/s eta 0:00:05
#    --- ------------------------------------ 3.4/38.8 MB 8.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.7/38.8 MB 7.5 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.8/38.8 MB 7.0 MB/s eta 0:00:05
#    ------ --------------------------------- 6.6/38.8 MB 6.8 MB/s eta 0:00:05
#    ------- -------------------------------- 7.6/38.8 MB 6.1 MB/s eta 0:00:06
#    -------- ------------------------------- 8.4/38.8 MB 5.7 MB/s eta 0:00:06
#    --------- ------------------------------ 9.2/38.8 MB 5.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.2/38.8 MB 5.5 MB/s eta 0:00:06
#    ----------- ---------------------------- 11.5/38.8 MB 5.5 MB/s eta 0:00:05
#    ------------- -------------------------- 13.1/38.8 MB 5.7 MB/s eta 0:00:05
# ...

# %%
# %pip install folium
